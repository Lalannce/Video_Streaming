# %%
#(Bola for 1% of packet Loss)

import matplotlib.pyplot as plt

# Data for BBR
BBR_x = [22.99, 22.75, 20.913, 22.74, 22.05]
BBR_y = [1.72, 1.68, 1.83, 1.61, -0.92]

# Data for BBRv2
BBRv2_x = [19.79, 19.47, 19.96, 19.45, 18.84]
BBRv2_y = [1.65, -0.94, 1.71, -0.79, 1.76]

# Data for Cubic
Cubic_x = [34.10, 33.53, 34.80, 34.01, 34.68]
Cubic_y = [1.86, 1.90, 1.79, 1.83, 1.80]

# Data for Reno
Reno_x = [48.66, 45.97, 46.19, 45.38, 43.56]
Reno_y = [1.78, 1.77, 1.84, 1.74, 1.85]

plt.figure(figsize=(5,3))
fontsize = 14
fontweight = 'bold'
# Create scatter plots for each Algorithm
plt.scatter(BBR_x, BBR_y, label='BBR', marker='o', color='green')
plt.scatter(BBRv2_x, BBRv2_y, label='BBRv2', marker='x', color='orange')
plt.scatter(Cubic_x, Cubic_y, label='Cubic', marker='^', color='red')
plt.scatter(Reno_x, Reno_y, label='Reno', marker='*', color='blue')
# Set y-coordinate axis range
plt.ylim(-20, 5)

plt.xticks(fontsize=fontsize, fontweight=fontweight)
plt.yticks(fontsize=fontsize, fontweight=fontweight)

# Add labels and legend
plt.xlabel('CWND in kb for 1% Packet Loss', fontsize = fontsize, fontweight='bold')
plt.ylabel('QoE', fontsize = fontsize, fontweight='bold')
plt.legend(fontsize='small', prop = dict(weight='bold'))

#plt.title('Grouped Scatter Plots')
plt.legend()
plt.savefig("QoEBcwndPacketLoss1.pdf", format="pdf", bbox_inches="tight")
# Show the plot
plt.show()

# %%
#(Bola for 5% of packet Loss)

import matplotlib.pyplot as plt

# Data for BBR
BBR_x = [21.11, 22.86, 21.97, 21.53, 21.33]
BBR_y = [-53.88, -59.88, -46.46, -35.79, -12.13]

# Data for BBRv2
BBRv2_x = [15.96, 16.79, 16.66, 18.25, 16.08]
BBRv2_y = [-104.81, -33.34, -6.41, -66.96, -22.54]

# Data for Cubic
Cubic_x = [15.24, 15.41, 14.83, 15.46, 14.95]
Cubic_y = [-6.64, -137.03, -157.82, -14.43, -92.02]

# Data for Reno
Reno_x = [19.44, 19.62, 19.70, 18.88, 20.62]
Reno_y = [-112.41, -64.56, -73.00, -32.99, -33.16]

plt.figure(figsize=(5,3))
fontsize = 14
fontweight = 'bold'
# Create scatter plots for each Algorithm
plt.scatter(BBR_x, BBR_y, label='BBR', marker='o', color='green')
plt.scatter(BBRv2_x, BBRv2_y, label='BBRv2', marker='x', color='orange')
plt.scatter(Cubic_x, Cubic_y, label='Cubic', marker='^', color='red')
plt.scatter(Reno_x, Reno_y, label='Reno', marker='*', color='blue')
# Set y-coordinate axis range
plt.ylim(-400, 0)

plt.xticks(fontsize=fontsize, fontweight=fontweight)
plt.yticks(fontsize=fontsize, fontweight=fontweight)

# Add labels and legend
plt.xlabel('CWND in kb for 5% Packet Loss', fontsize = fontsize, fontweight='bold')
plt.ylabel('QoE', fontsize = fontsize, fontweight='bold')
plt.legend(fontsize='small', prop = dict(weight='bold'))

#plt.title('Grouped Scatter Plots')
plt.legend()
plt.savefig("QoEBcwndPacketLoss5.pdf", format="pdf", bbox_inches="tight")
# Show the plot
plt.show()

# %%
#(Bola for 10% of packet Loss)

import matplotlib.pyplot as plt

# Data for BBR
BBR_x = [22.54, 24.40, 22.09, 22.54, 23.78]
BBR_y = [-6.68, -1.67, -54.19, -16.83, -138.86]

# Data for BBRv2
BBRv2_x = [17.17, 16.21, 16.66, 18.25, 16.08]
BBRv2_y = [-219.18, -280.62, -60.09, -136.65, -60.64]

# Data for Cubic
Cubic_x = [15.24, 15.41, 15.72, 15.41, 15.12]
Cubic_y = [-328.22, -364.48, -260.96, -85.85, -184.51]

# Data for Reno
Reno_x = [13.22, 13.47, 10.86, 13.59, 13.33]
Reno_y = [-123.60, -89.26179875506301, -304.27, -158.07, -288.02]

plt.figure(figsize=(5, 3))
fontsize = 14
fontweight = 'bold'
# Create scatter plots for each Algorithm
plt.scatter(BBR_x, BBR_y, label='BBR', marker='o', color='green')
plt.scatter(BBRv2_x, BBRv2_y, label='BBRv2', marker='x', color='orange')
plt.scatter(Cubic_x, Cubic_y, label='Cubic', marker='^', color='red')
plt.scatter(Reno_x, Reno_y, label='Reno', marker='*', color='blue')
# Set y-coordinate axis range
plt.ylim(-400, 0)

plt.xticks(fontsize=fontsize, fontweight=fontweight)
plt.yticks(fontsize=fontsize, fontweight=fontweight)

plt.xlabel('CWND in kb for 10% Packet Loss', fontsize = fontsize, fontweight='bold')
plt.ylabel('QoE', fontsize = fontsize, fontweight='bold')
plt.legend(fontsize='small', prop = dict(weight='bold'))

plt.savefig("QoEBcwndPacketLoss10.pdf", format="pdf", bbox_inches="tight")

# Show the plot
plt.show()

# %%
#(Bola for 1% of Bitrate)

import matplotlib.pyplot as plt

# Data for BBR
BBR_x = [22.99, 22.75, 20.913, 22.74, 22.05]
BBR_y = [827.45, 1376.19, 1374.19, 1457.14, 1500.0]

# Data for BBRv2
BBRv2_x = [19.79, 19.47, 19.96, 19.45, 18.84]
BBRv2_y = [1376.19, 978.43, 1376.19, 1500.0, 1182.92]

# Data for Cubic
Cubic_x = [34.10, 33.53, 34.80, 34.01, 34.68]
Cubic_y = [1252.38, 1376.19, 509.09, 1164.51, 1314.28]

# Data for Reno
Reno_x = [48.66, 45.97, 46.19, 45.38, 43.56]
Reno_y = [1358.41, 1038.70, 1314.28, 1190.47, 1248.38]

plt.figure(figsize=(5,3))
fontsize = 14
fontweight = 'bold'
# Create scatter plots for each Algorithm
plt.scatter(BBR_x, BBR_y, label='BBR', marker='o', color='green')
plt.scatter(BBRv2_x, BBRv2_y, label='BBRv2', marker='x', color='orange')
plt.scatter(Cubic_x, Cubic_y, label='Cubic', marker='^', color='red')
plt.scatter(Reno_x, Reno_y, label='Reno', marker='*', color='blue')
# Set y-coordinate axis range
plt.ylim(0, 1600)

plt.xticks(fontsize=fontsize, fontweight=fontweight)
plt.yticks(fontsize=fontsize, fontweight=fontweight)

plt.xlabel('CWND in kb for 1% Packet Loss', fontsize = fontsize, fontweight='bold')
plt.ylabel('Bitrate', fontsize = fontsize, fontweight='bold')
plt.legend(fontsize='small', prop = dict(weight='bold'))

plt.legend()
plt.savefig("BRBcwndPacketLoss1.pdf", format="pdf", bbox_inches="tight")

# Show the plot
plt.show()

# %%
#(Bola for 5% of packet Loss Bitrate)

import matplotlib.pyplot as plt

# Data for BBR
BBR_x = [21.11, 22.86, 21.97, 21.53, 21.33]
BBR_y = [706.79, 810.75, 750.0, 1083.66, 724.25]

# Data for BBRv2
BBRv2_x = [15.96, 16.79, 16.66, 18.25, 16.08]
BBRv2_y = [741.50, 613.91, 800.94, 662.26, 918.54]

# Data for Cubic
Cubic_x = [15.24, 15.41, 14.83, 15.46, 14.95]
Cubic_y = [962.96, 831.46, 710.75, 918.75, 719.00]

# Data for Reno
Reno_x = [19.44, 19.62, 19.70, 18.88, 20.62]
Reno_y = [1043.66, 889.76, 912.93, 901.20, 781.56]

plt.figure(figsize=(5,3))
fontsize = 14
fontweight = 'bold'
# Create scatter plots for each Algorithm
plt.scatter(BBR_x, BBR_y, label='BBR', marker='o', color='green')
plt.scatter(BBRv2_x, BBRv2_y, label='BBRv2', marker='x', color='orange')
plt.scatter(Cubic_x, Cubic_y, label='Cubic', marker='^', color='red')
plt.scatter(Reno_x, Reno_y, label='Reno', marker='*', color='blue')
# Set y-coordinate axis range
plt.ylim(0, 1600)

plt.xticks(fontsize=fontsize, fontweight=fontweight)
plt.yticks(fontsize=fontsize, fontweight=fontweight)

plt.xlabel('CWND in kb for 5% Packet Loss', fontsize = fontsize, fontweight='bold')
plt.ylabel('Bitrate', fontsize = fontsize, fontweight='bold')
plt.legend(fontsize='small', prop = dict(weight='bold'))

#plt.title('Grouped Scatter Plots')
plt.legend()
plt.savefig("BRBcwndPacketLoss5.pdf", format="pdf", bbox_inches="tight")
# Show the plot
plt.show()

# %%
#(Bola for 10% of packet Loss Bitrate)

import matplotlib.pyplot as plt

# Data for BBR
BBR_x = [22.54, 24.40, 22.09, 22.54, 23.78]
BBR_y = [558.09, 276.12, 517.38, 392.80, 513.99]

# Data for BBRv2
BBRv2_x = [17.17, 16.21, 16.66, 18.25, 16.08]
BBRv2_y = [389.87, 417.84, 338.77, 375.15, 267.39]

# Data for Cubic
Cubic_x = [15.24, 15.41, 15.72, 15.41, 15.12]
Cubic_y = [323.18, 452.88, 297.94, 422.14, 414.69]

# Data for Reno
Reno_x = [13.22, 13.47, 10.86, 13.59, 13.33]
Reno_y = [520.27, 386.93, 386.80, 362.80, 524.05]

plt.figure(figsize=(5, 3))
fontsize = 14
fontweight = 'bold'
# Create scatter plots for each Algorithm
plt.scatter(BBR_x, BBR_y, label='BBR', marker='o', color='green')
plt.scatter(BBRv2_x, BBRv2_y, label='BBRv2', marker='x', color='orange')
plt.scatter(Cubic_x, Cubic_y, label='Cubic', marker='^', color='red')
plt.scatter(Reno_x, Reno_y, label='Reno', marker='*', color='blue')
# Set y-coordinate axis range
plt.ylim(0, 1600)

plt.xticks(fontsize=fontsize, fontweight=fontweight)
plt.yticks(fontsize=fontsize, fontweight=fontweight)

# Add labels and legend
plt.xlabel('CWND in kb for 10% Packet Loss', fontsize = fontsize, fontweight='bold')
plt.ylabel('Bitrate', fontsize = fontsize, fontweight='bold')
plt.legend(fontsize='small', prop = dict(weight='bold'))
plt.savefig("BRBcwndPacketLoss10.pdf", format="pdf", bbox_inches="tight")

# Show the plot
plt.show()

# %%
#(Bola for 1% of Stall Rate)

import matplotlib.pyplot as plt

# Data for BBR
BBR_x = [22.99, 22.75, 20.913, 22.74, 22.05]
BBR_y = [0, 0, 0, 0, 1]

# Data for BBRv2
BBRv2_x = [19.79, 19.47, 19.96, 19.45, 18.84]
BBRv2_y = [0, 1, 0, 0.9, 0]

# Data for Cubic
Cubic_x = [34.10, 33.53, 34.80, 34.01, 34.68]
Cubic_y = [0, 0, 0, 0, 0]

# Data for Reno
Reno_x = [48.66, 45.97, 46.19, 45.38, 43.56]
Reno_y = [0, 0, 0, 0, 0]

plt.figure(figsize=(5,3))
fontsize = 14
fontweight = 'bold'
# Create scatter plots for each Algorithm
plt.scatter(BBR_x, BBR_y, label='BBR', marker='o', color='green')
plt.scatter(BBRv2_x, BBRv2_y, label='BBRv2', marker='x', color='orange')
plt.scatter(Cubic_x, Cubic_y, label='Cubic', marker='^', color='red')
plt.scatter(Reno_x, Reno_y, label='Reno', marker='*', color='blue')
# Set y-coordinate axis range
plt.ylim(0, 150)

plt.xticks(fontsize=fontsize, fontweight=fontweight)
plt.yticks(fontsize=fontsize, fontweight=fontweight)

# Add labels and legend
plt.xlabel('CWND in kb for 1% Packet Loss', fontsize = fontsize, fontweight='bold')
plt.ylabel('Stall Time in second', fontsize = fontsize, fontweight='bold')
plt.legend(fontsize='small', prop = dict(weight='bold'))

#plt.title('Grouped Scatter Plots')
plt.legend()
plt.savefig("BTBcwndPacketLoss1.pdf", format="pdf", bbox_inches="tight")

# Show the plot
plt.show()

# %%
#(Bola for 5% of packet Loss Bitrate)

import matplotlib.pyplot as plt

# Data for BBR
BBR_x = [21.11, 22.86, 21.97, 21.53, 21.33]
BBR_y = [20.7, 23.0, 17.9, 13.9, 5.0]

# Data for BBRv2
BBRv2_x = [15.96, 16.79, 16.66, 18.25, 16.08]
BBRv2_y = [39.8, 12.8, 2.9, 25.6, 8.9]

# Data for Cubic
Cubic_x = [15.24, 15.41, 14.83, 15.46, 14.95]
Cubic_y = [3.0, 52.0, 59.7, 5.9, 35.0]

# Data for Reno
Reno_x = [19.44, 19.62, 19.70, 18.88, 20.62]
Reno_y = [42.8, 24.8, 28.0, 12.8, 13.0]

plt.figure(figsize=(5,3))
fontsize = 14
fontweight = 'bold'
# Create scatter plots for each Algorithm
plt.scatter(BBR_x, BBR_y, label='BBR', marker='o', color='green')
plt.scatter(BBRv2_x, BBRv2_y, label='BBRv2', marker='x', color='orange')
plt.scatter(Cubic_x, Cubic_y, label='Cubic', marker='^', color='red')
plt.scatter(Reno_x, Reno_y, label='Reno', marker='*', color='blue')
# Set y-coordinate axis range
plt.ylim(0, 150)

plt.xticks(fontsize=fontsize, fontweight=fontweight)
plt.yticks(fontsize=fontsize, fontweight=fontweight)

# Add labels and legend
plt.xlabel('CWND in kb for 5% Packet Loss', fontsize = fontsize, fontweight='bold')
plt.ylabel('Stall Time in second', fontsize = fontsize, fontweight='bold')
plt.legend(fontsize='small', prop = dict(weight='bold'))

#plt.title('Grouped Scatter Plots')
plt.legend()
plt.savefig("BTBcwndPacketLoss5.pdf", format="pdf", bbox_inches="tight")

# Show the plot
plt.show()

# %%
#(Bola for 10% of packet Loss Bitrate)

import matplotlib.pyplot as plt

# Data for BBR
BBR_x = [22.54, 24.40, 22.09, 22.54, 23.78]
BBR_y = [55.6, 77.8, 31.9, 75.6, 66.8]

# Data for BBRv2
BBRv2_x = [17.17, 16.21, 16.66, 18.25, 16.08]
BBRv2_y = [82.6, 105.7, 22.8, 51.5, 22.8]

# Data for Cubic
Cubic_x = [15.24, 15.41, 15.72, 15.41, 15.12]
Cubic_y = [123.5, 137.2, 98.2, 32.4, 69.5]

# Data for Reno
Reno_x = [13.22, 13.47, 10.86, 13.59, 13.33]
Reno_y = [46.7, 140.5, 114.5, 59.7, 108.5]

plt.figure(figsize=(5, 3))
fontsize = 12
fontweight = 'bold'
# Create scatter plots for each Algorithm
plt.scatter(BBR_x, BBR_y, label='BBR', marker='o', color='green')
plt.scatter(BBRv2_x, BBRv2_y, label='BBRv2', marker='x', color='orange')
plt.scatter(Cubic_x, Cubic_y, label='Cubic', marker='^', color='red')
plt.scatter(Reno_x, Reno_y, label='Reno', marker='*', color='blue')
# Set y-coordinate axis range
plt.ylim(0, 150)

plt.xticks(fontsize=fontsize, fontweight=fontweight)
plt.yticks(fontsize=fontsize, fontweight=fontweight)

# Add labels and legend
plt.xlabel('CWND in kb for 10% Packet Loss', fontsize = fontsize, fontweight='bold')
plt.ylabel('Stall Time in second', fontsize = fontsize, fontweight='bold')
plt.legend(fontsize='small', prop = dict(weight='bold'))

plt.savefig("BTBcwndPacketLoss10.pdf", format="pdf", bbox_inches="tight")

# Show the plot
plt.show()

# %%
############## Throuput Algorithm started ####################

# %%
#(Throughput BBR 1% of packet Loss)
import matplotlib.pyplot as plt

# Data for BBR
BBR_x = [23.69, 20.41, 23.31, 22.34, 22.25]
BBR_y = [1.78, 1.69, 1.73, 1.68, 1.75]

# Data for BBRv2
BBRv2_x = [19.60, 19.90, 19.95, 19.12, 20.16]
BBRv2_y = [1.78, 1.69, 1.65, 1.78, 1.39]

# Data for Cubic
Cubic_x = [34.10, 33.53, 34.80, 34.01, 34.68]
Cubic_y = [1.73, 1.78, 1.81, 1.78, 1.81]

# Data for Reno
Reno_x = [48.34, 45.76, 45.59, 44.52, 45.02]
Reno_y = [1.89, 1.93, 1.86, 1.89, 1.72]

plt.figure(figsize=(5,3))
fontsize = 14
fontweight = 'bold'
# Create scatter plots for each Algorithm
plt.scatter(BBR_x, BBR_y, label='BBR', marker='o', color='green')
plt.scatter(BBRv2_x, BBRv2_y, label='BBRv2', marker='x', color='orange')
plt.scatter(Cubic_x, Cubic_y, label='Cubic', marker='^', color='red')
plt.scatter(Reno_x, Reno_y, label='Reno', marker='*', color='blue')
# Set y-coordinate axis range
plt.ylim(-20, 5)

plt.xticks(fontsize=fontsize, fontweight=fontweight)
plt.yticks(fontsize=fontsize, fontweight=fontweight)

# Add labels and legend
plt.xlabel('CWND in kb for 1% Packet Loss', fontsize = fontsize, fontweight='bold')
plt.ylabel('QoE', fontsize = fontsize, fontweight='bold')
plt.legend(fontsize='small', prop = dict(weight='bold'))

#plt.title('Grouped Scatter Plots')
plt.legend()
plt.savefig("QoETcwndPacketLoss1.pdf", format="pdf", bbox_inches="tight")
# Show the plot
plt.show()

# %%
#(Throughput QoE 5% of packet Loss)
import matplotlib.pyplot as plt

# Data for BBR
BBR_x = [20.82, 22.34, 20.41, 21.00, 21.22]
BBR_y = [-6.68, -1.67, -54.19, -16.83, -138.86]

# Data for BBRv2
BBRv2_x = [17.06, 16.73, 16.54, 17.09, 16.93]
BBRv2_y = [-14.12, -48.06, -62.26, -51.87, -72.82]

# Data for Cubic
Cubic_x = [15.24, 15.41, 14.83, 15.46, 14.95]
Cubic_y = [-43.26, -56.85, -35.69, -85.16, -131.21]

# Data for Reno
Reno_x = [18.25, 20.23, 19.90, 20.78, 19.90]
Reno_y = [-72.32, -40.84, -35.45, -27.51, -72.69]

plt.figure(figsize=(5,3))
fontsize = 14
fontweight = 'bold'
# Create scatter plots for each Algorithm
plt.scatter(BBR_x, BBR_y, label='BBR', marker='o', color='green')
plt.scatter(BBRv2_x, BBRv2_y, label='BBRv2', marker='x', color='orange')
plt.scatter(Cubic_x, Cubic_y, label='Cubic', marker='^', color='red')
plt.scatter(Reno_x, Reno_y, label='Reno', marker='*', color='blue')
# Set y-coordinate axis range
plt.ylim(-400, 0)

plt.xticks(fontsize=fontsize, fontweight=fontweight)
plt.yticks(fontsize=fontsize, fontweight=fontweight)

# Add labels and legend
plt.xlabel('CWND in kb for 5% Packet Loss', fontsize = fontsize, fontweight='bold')
plt.ylabel('QoE', fontsize = fontsize, fontweight='bold')
plt.legend(fontsize='small', prop = dict(weight='bold'))

#plt.title('Grouped Scatter Plots')
plt.legend()
plt.savefig("QoETcwndPacketLoss5.pdf", format="pdf", bbox_inches="tight")
# Show the plot
plt.show()

# %%
#(Throughput QoE 10% of packet Loss)
import matplotlib.pyplot as plt

# Data for BBR
BBR_x = [21.50, 22.38, 22.86, 20.43, 21.00]
BBR_y = [-68.29, -184.51, -152.39, -184.79, -112.74]

# Data for BBRv2
BBRv2_x = [15.81, 15.76, 14.85, 15.81, 16.07]
BBRv2_y = [-298.92, -108.09, -202.13, -117.39, -57.35]

# Data for Cubic
Cubic_x = [10.91, 11.44, 11.16, 11.10, 11.02]
Cubic_y = [-209.04, -220.80, -42.54, -192.70, -381.45]

# Data for Reno
Reno_x = [10.37, 13.51, 13.66, 13.43, 13.34]
Reno_y = [-334.53, -110.15, -70.22, -328.32, -131.53]

plt.figure(figsize=(5,3))
fontsize = 14
fontweight = 'bold'
# Create scatter plots for each Algorithm
plt.scatter(BBR_x, BBR_y, label='BBR', marker='o', color='green')
plt.scatter(BBRv2_x, BBRv2_y, label='BBRv2', marker='x', color='orange')
plt.scatter(Cubic_x, Cubic_y, label='Cubic', marker='^', color='red')
plt.scatter(Reno_x, Reno_y, label='Reno', marker='*', color='blue')
# Set y-coordinate axis range
plt.ylim(-400, 0)

plt.xticks(fontsize=fontsize, fontweight=fontweight)
plt.yticks(fontsize=fontsize, fontweight=fontweight)

# Add labels and legend
plt.xlabel('CWND in kb for 10% Packet Loss', fontsize = fontsize, fontweight='bold')
plt.ylabel('QoE', fontsize = fontsize, fontweight='bold')
plt.legend(fontsize='small', prop = dict(weight='bold'))

#plt.title('Grouped Scatter Plots')
plt.legend()
plt.savefig("QoEBcwndPacketLoss10.pdf", format="pdf", bbox_inches="tight")
# Show the plot
plt.show()

# %%
########## Bandwidth variation Bola  ####
import matplotlib.pyplot as plt
import numpy as np
# Data
x_values = [0.5, 1, 1.5, 2]
BBR = [10.74, 11.68, 16.16, 20.79]
BBRv2 = [8.48, 11.99, 14.92, 19.32]
Reno = [145.63, 364.18, 464.26, 599.00]
Cubic = [127.54, 280.43, 335.66, 405.52]

plt.figure(figsize=(5,3))
fontsize = 14
fontweight = 'bold'


# Plotting the line graph
plt.plot(x_values, BBR, label='BBR', marker='o',linewidth=3)#, color='green')
plt.plot(x_values, BBRv2, label='BBRv2', marker='x',linewidth=3)#, color='orange')
plt.plot(x_values, Cubic, label='Cubic', marker='^',linewidth=3)#, color='red')
plt.plot(x_values, Reno, label='Reno', marker='*',linewidth=3)#, color='blue')

plt.xticks([0.5,1,1.5,2], fontsize=fontsize, fontweight=fontweight)
plt.yticks(np.arange(0,600,100), fontsize=fontsize, fontweight=fontweight)


#plt.xticks(fontsize=fontsize, fontweight=fontweight)
#plt.yticks(fontsize=fontsize, fontweight=fontweight)
plt.grid(axis='y')
# Adding labels and title
plt.xlabel('Bandwidth in Mbps', fontsize=fontsize, fontweight='bold')
plt.ylabel('Congestion window', fontsize=fontsize, fontweight='bold')
plt.legend(fontsize='small', prop = dict(weight='bold'))
plt.savefig("BcwndBW.pdf", format="pdf", bbox_inches="tight")
#plt.title('Line Graph of Algorithm Values')
plt.legend()

# %%
import numpy as np

# %%
#average_value = sum(data_list) / len(data_list)
########## Bandwidth variation Bola  ####
import matplotlib.pyplot as plt

# Data for 1%
BBR_1 = [22.99, 22.75, 20.913, 22.74, 22.05]
# Data for BBRv2
BBRv2_1 = [19.79, 19.47, 19.96, 19.45, 18.84]
# Data for Cubic
Cubic_1 = [34.10, 33.53, 34.80, 34.01, 34.68]
# Data for Reno
Reno_1 = [48.66, 45.97, 46.19, 45.38, 43.56]

# Data for 5%
BBR_5 = [21.11, 22.86, 21.97, 21.53, 21.33]
# Data for BBRv2
BBRv2_5 = [15.96, 16.79, 16.66, 18.25, 16.08]
# Data for Cubic
Cubic_5 = [15.24, 15.41, 14.83, 15.46, 14.95]
# Data for Reno
Reno_5 = [19.44, 19.62, 19.70, 18.88, 20.62]

# Data for 10%
BBR_10 = [22.54, 24.40, 22.09, 22.54, 23.78]
# Data for BBRv2
BBRv2_10 = [17.17, 16.21, 16.66, 18.25, 16.08]
# Data for Cubic
Cubic_10 = [15.24, 15.41, 15.72, 15.41, 15.12]
# Data for Reno
Reno_10 = [13.22, 13.47, 10.86, 13.59, 13.33]


# Data
x_values = [1, 5, 10]
BBR = [sum(BBR_1) / len(BBR_1), sum(BBR_5) / len(BBR_5), sum(BBR_10) / len(BBR_10)]
BBRv2 = [sum(BBRv2_1) / len(BBRv2_5), sum(BBRv2_5) / len(BBRv2_5), sum(BBRv2_10) / len(BBRv2_10)]
Cubic = [sum(Cubic_1) / len(Cubic_1), sum(Cubic_5) / len(Cubic_5), sum(Cubic_10) / len(Cubic_10)]
Reno = [sum(Reno_1) / len(Reno_1), sum(Reno_5) / len(Reno_5), sum(Reno_10) / len(Reno_10)]

plt.figure(figsize=(5,3))
fontsize = 14
fontweight = 'bold'


# Plotting the line graph
plt.plot(x_values, BBR, label='BBR', marker='o',linewidth=3)#, color='green')
plt.plot(x_values, BBRv2, label='BBRv2', marker='x',linewidth=3)#, color='orange')
plt.plot(x_values, Cubic, label='Cubic', marker='^',linewidth=3)#, color='red')
plt.plot(x_values, Reno, label='Reno', marker='*',linewidth=3)#, color='blue')
plt.xlim([1,10])
plt.xticks([1,5,10], fontsize=fontsize, fontweight=fontweight)
plt.yticks(np.arange(0,51,10), fontsize=fontsize, fontweight=fontweight)
plt.grid(axis='y')
# Adding labels and title
plt.xlabel('Packet Loss in %', fontsize=fontsize, fontweight='bold')
plt.ylabel('Congestion window', fontsize=fontsize, fontweight='bold')
plt.legend(fontsize='small', prop = dict(weight='bold'))
# plt.grid()
#plt.savefig("BcwndBW.pdf", format="pdf", bbox_inches="tight")
#plt.title('Line Graph of Algorithm Values')
plt.legend()
plt.show()
