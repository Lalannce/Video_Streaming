# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
dftpb = pd.read_csv('/media/lalan/StudyMaterial/WorkingD/Result/BBR_Throu_PacketLoss.csv', index_col=0)
dftpb2 = pd.read_csv('/media/lalan/StudyMaterial/WorkingD/Result/BBRv2_Throu_PacketLoss.csv', index_col=0)
dftpc = pd.read_csv('/media/lalan/StudyMaterial/WorkingD/Result/Cubic_Throu_PacketLoss.csv', index_col=0)
dftpr = pd.read_csv('/media/lalan/StudyMaterial/WorkingD/Result/Reno_Throu_PacketLoss.csv', index_col=0)
bbr_y = np.array([0.0, 28.60, 53.02])  # BBR data

# %%
dftpr
# Out:
#              Mean of Buffer Time  Mean of bitrate
# mean of QoE
#  1.861336                    0.0      1231.869437
# -18.232782                  74.5      1180.166280
# -49.766158                 192.6      1012.864219
# -94.510363                 359.2       827.766143
# -194.955234                735.6       512.218622

# %%
# Packet Loss vs QoE(TYPE 1 Direct)
# Result  Packet Loss vs QoE (Throughput)
import matplotlib.pyplot as plt
import numpy as np

# Data
variations = [1, 3, 5, 7, 10]
x_positions = np.arange(len(variations))


# Data
bbr_y = np.array([1.73, -17.21, -43.64, -79.21, -140.54])  # BBR data
bbrv2_y = np.array([1.05, -21.59, -49.83, -82.46, -156.77])  # BBRv2 data
cubic_y = np.array([1.78, -14.82, -70.43, -156.44, -209.31])  # Cubic data
reno_y = np.array([1.86, -18.23, -49.76, -94.51, -194.95])  # CReno data


# Bar width
bar_width = 0.2
plt.figure(figsize=(5,3))
fontsize = 12
fontweight = 'bold'

# Plot bar graphs with logarithmic Y-axis for BBR, BBRv2, Reno, and Cubic
plt.bar(x_positions - 0.4, bbr_y, width=bar_width, label='BBR', hatch='/', color='salmon')
plt.bar(x_positions - 0.2, bbrv2_y, width=bar_width, label='BBRv2', hatch='.', color='darkseagreen')
plt.bar(x_positions, cubic_y, width=bar_width, label='Cubic', hatch='\\', color='bisque')
plt.bar(x_positions + 0.2, reno_y, width=bar_width, label='Reno', hatch='-', color='lightsteelblue')

# Set x-axis labels
#plt.xticks(x_positions, variations)
plt.xticks(x_positions, variations, fontsize=fontsize, fontweight=fontweight)
plt.yticks(fontsize=fontsize, fontweight=fontweight)

# Adding labels and title
plt.xlabel('Packet Loss(in %)', fontweight='bold', fontsize=15)
plt.ylabel('QoE', fontweight='bold', fontsize=15)
#plt.text(2.9,5,'$\mathcal{x}$',fontsize=20,fontdict=dict(color='red'))
#plt.text(3.1,5,'$\mathcal{x}$',fontsize=20,fontdict=dict(color='red'))

# Add a legend
plt.legend(fontsize='x-small', prop = dict(weight='bold'))
plt.grid(axis = 'y')
# Show the plot
plt.tight_layout()
plt.savefig("QoE_Throu_PacketLoss.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
dftpr
# Out:
#              Mean of Buffer Time  Mean of bitrate
# mean of QoE
#  1.861336                    0.0      1231.869437
# -18.232782                  74.5      1180.166280
# -49.766158                 192.6      1012.864219
# -94.510363                 359.2       827.766143
# -194.955234                735.6       512.218622

# %%
# Packet Loss vs QoE(TYPE 1 Direct)
# Result  Packet Loss vs Buffer Time (Throughput)
import matplotlib.pyplot as plt
import numpy as np

# Data
variations = [1, 3, 5, 7, 10]
x_positions = np.arange(len(variations))


# Data
bbr_y = np.array([0, 7.04, 16.84, 30.08, 53.02])  # BBR data
bbrv2_y = np.array([0.22, 8.680, 19.20, 31.350, 59.160])  # BBRv2 data
cubic_y = np.array([0, 6.16, 26.94, 59.12, 78.78])  # Cubic data
reno_y = np.array([0, 7.45, 19.26, 35.92, 73.56])  # CReno data


# Bar width
bar_width = 0.2
plt.figure(figsize=(5,3))
fontsize = 12
fontweight = 'bold'

# Plot bar graphs with logarithmic Y-axis for BBR, BBRv2, Reno, and Cubic
plt.bar(x_positions - 0.4, bbr_y, width=bar_width, label='BBR', hatch='/', color='salmon')
plt.bar(x_positions - 0.2, bbrv2_y, width=bar_width, label='BBRv2', hatch='.', color='darkseagreen')
plt.bar(x_positions, cubic_y, width=bar_width, label='Cubic', hatch='\\', color='bisque')
plt.bar(x_positions + 0.2, reno_y, width=bar_width, label='Reno', hatch='-', color='lightsteelblue')

# Set x-axis labels
#plt.xticks(x_positions, variations)
plt.xticks(x_positions, variations, fontsize=fontsize, fontweight=fontweight)
plt.yticks(fontsize=fontsize, fontweight=fontweight)

# Adding labels and title
plt.xlabel('Packet Loss(in %)', fontweight='bold', fontsize=15)
plt.ylabel('Buffer Time(in sec)', fontweight='bold', fontsize=15)
#plt.text(2.9,5,'$\mathcal{x}$',fontsize=20,fontdict=dict(color='red'))
#plt.text(3.1,5,'$\mathcal{x}$',fontsize=20,fontdict=dict(color='red'))

# Add a legend
plt.legend(fontsize='x-small', prop = dict(weight='bold'))
plt.grid(axis = 'y')
# Show the plot
plt.tight_layout()
plt.savefig("BufferTime_Throu_PacketLoss.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
dftpb
# Out:
#              Mean of Buffer Time  Mean of bitrate
# mean of QoE
#  1.732047                    0.0      1376.751541
# -17.215526                  70.4       895.782811
# -43.649720                 168.4       676.693864
# -79.216589                 300.8       644.521752
# -140.548805                530.2       404.349542

# %%
# Packet Loss vs QoE(TYPE 1 Direct)
# Result  Packet Loss vs Bitrate (Throughput)
import matplotlib.pyplot as plt
import numpy as np

# Data
variations = [1, 3, 5, 7, 10]
x_positions = np.arange(len(variations))


# Data
bbr_y = np.array([1376.75, 895.78, 676.69, 644.52, 404.34])  # BBR data
bbrv2_y = np.array([1251.40, 1065.54, 833.61, 568.63, 506.18])  # BBRv2 data
cubic_y = np.array([1313.82, 1071.65, 751.34, 564.22, 339.52])  # Cubic data
reno_y = np.array([1231.86, 1180.16, 1012.86, 827.76, 512.21])  # CReno data
1012.86

# Bar width
bar_width = 0.2
plt.figure(figsize=(5,3))
fontsize = 12
fontweight = 'bold'

# Plot bar graphs with logarithmic Y-axis for BBR, BBRv2, Reno, and Cubic
plt.bar(x_positions - 0.4, bbr_y, width=bar_width, label='BBR', hatch='/', color='salmon')
plt.bar(x_positions - 0.2, bbrv2_y, width=bar_width, label='BBRv2', hatch='.', color='darkseagreen')
plt.bar(x_positions, cubic_y, width=bar_width, label='Cubic', hatch='\\', color='bisque')
plt.bar(x_positions + 0.2, reno_y, width=bar_width, label='Reno', hatch='-', color='lightsteelblue')

# Set x-axis labels
#plt.xticks(x_positions, variations)
plt.xticks(x_positions, variations, fontsize=fontsize, fontweight=fontweight)
plt.yticks(fontsize=fontsize, fontweight=fontweight)

# Adding labels and title
plt.xlabel('Packet Loss(in %)', fontweight='bold', fontsize=15)
plt.ylabel('Average Bitrate', fontweight='bold', fontsize=15)
#plt.text(2.9,5,'$\mathcal{x}$',fontsize=20,fontdict=dict(color='red'))
#plt.text(3.1,5,'$\mathcal{x}$',fontsize=20,fontdict=dict(color='red'))

# Add a legend
plt.legend(fontsize='x-small', prop = dict(weight='bold'))
plt.grid(axis = 'y')
# Show the plot
plt.tight_layout()
plt.savefig("AvgBitRate_Throu_PacketLoss.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
dfbpb = pd.read_csv('/media/lalan/StudyMaterial/WorkingD/Result/BBR_Bola_PacketLoss.csv', index_col=0)
dfbpb2 = pd.read_csv('/media/lalan/StudyMaterial/WorkingD/Result/BBRv2_Bola_PacketLoss.csv', index_col=0)
dfbpc = pd.read_csv('/media/lalan/StudyMaterial/WorkingD/Result/Cubic_Bola_PacketLoss.csv', index_col=0)
dfbpr = pd.read_csv('/media/lalan/StudyMaterial/WorkingD/Result/Reno_Bola_PacketLoss.csv', index_col=0)
dfbpr
# Out:
#              Mean of Buffer Time  Mean of bitrate
# mean of QoE
#  1.800427                    0.0      1230.054904
# -14.852698                  62.0      1268.982629
# -63.227208                 242.8       905.824698
# -87.453170                 332.5       694.371398
# -209.899560                791.0       698.077884

# %%
# Packet Loss vs QoE(TYPE 1 Direct)
# Result  Packet Loss vs QoE (Bola)
import matplotlib.pyplot as plt
import numpy as np

# Data
variations = [1, 3, 5, 7, 10]
x_positions = np.arange(len(variations))


# Data
bbr_y = np.array([1.18, -16.57, -41.63, -69.69, -163.20])  # BBR data
bbrv2_y = np.array([0.43, -26.61, -46.81, -79.98, -151.44])  # BBRv2 data
cubic_y = np.array([1.83, -17.56, -81.59, -98.13, -244.80])  # Cubic data
reno_y = np.array([1.80, -14.85, -63.22, -87.45, -209.89])  # CReno data


# Bar width
bar_width = 0.2
plt.figure(figsize=(5,3))
fontsize = 12
fontweight = 'bold'

# Plot bar graphs with logarithmic Y-axis for BBR, BBRv2, Reno, and Cubic
plt.bar(x_positions - 0.4, bbr_y, width=bar_width, label='BBR', hatch='/', color='salmon')
plt.bar(x_positions - 0.2, bbrv2_y, width=bar_width, label='BBRv2', hatch='.', color='darkseagreen')
plt.bar(x_positions, cubic_y, width=bar_width, label='Cubic', hatch='\\', color='bisque')
plt.bar(x_positions + 0.2, reno_y, width=bar_width, label='Reno', hatch='-', color='lightsteelblue')

# Set x-axis labels
#plt.xticks(x_positions, variations)
plt.xticks(x_positions, variations, fontsize=fontsize, fontweight=fontweight)
plt.yticks(fontsize=fontsize, fontweight=fontweight)

# Adding labels and title
plt.xlabel('Packet Loss(in %)', fontweight='bold', fontsize=15)
plt.ylabel('QoE', fontweight='bold', fontsize=15)
#plt.text(2.9,5,'$\mathcal{x}$',fontsize=20,fontdict=dict(color='red'))
#plt.text(3.1,5,'$\mathcal{x}$',fontsize=20,fontdict=dict(color='red'))

# Add a legend
plt.legend(fontsize='x-small', prop = dict(weight='bold'))
plt.grid(axis = 'y')
# Show the plot
plt.tight_layout()
plt.savefig("QoE_Bola_PacketLoss.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
dfbpr
# Out:
#              Mean of Buffer Time  Mean of bitrate
# mean of QoE
#  1.800427                    0.0      1230.054904
# -14.852698                  62.0      1268.982629
# -63.227208                 242.8       905.824698
# -87.453170                 332.5       694.371398
# -209.899560                791.0       698.077884

# %%
# Packet Loss vs QoE(TYPE 1 Direct)
# Result  Packet Loss vs Buffer Time (Bola)
import matplotlib.pyplot as plt
import numpy as np

# Data
variations = [1, 3, 5, 7, 10]
x_positions = np.arange(len(variations))


# Data
bbr_y = np.array([0.2, 6.74, 16.10, 26.46, 61.54])  # BBR data
bbrv2_y = np.array([0.47, 10.52, 18.00, 30.44, 57.08])  # BBRv2 data
cubic_y = np.array([0, 7.12, 31.12, 37.12, 92.16])  # Cubic data
reno_y = np.array([0, 6.20, 24.28, 33.25, 79.10])  # CReno data


# Bar width
bar_width = 0.2
plt.figure(figsize=(5,3))
fontsize = 12
fontweight = 'bold'

# Plot bar graphs with logarithmic Y-axis for BBR, BBRv2, Reno, and Cubic
plt.bar(x_positions - 0.4, bbr_y, width=bar_width, label='BBR', hatch='/', color='salmon')
plt.bar(x_positions - 0.2, bbrv2_y, width=bar_width, label='BBRv2', hatch='.', color='darkseagreen')
plt.bar(x_positions, cubic_y, width=bar_width, label='Cubic', hatch='\\', color='bisque')
plt.bar(x_positions + 0.2, reno_y, width=bar_width, label='Reno', hatch='-', color='lightsteelblue')

# Set x-axis labels
#plt.xticks(x_positions, variations)
plt.xticks(x_positions, variations, fontsize=fontsize, fontweight=fontweight)
plt.yticks(fontsize=fontsize, fontweight=fontweight)

# Adding labels and title
plt.xlabel('Packet Loss(in %)', fontweight='bold', fontsize=15)
plt.ylabel('Buffer Time(in secs)', fontweight='bold', fontsize=15)
#plt.text(2.9,5,'$\mathcal{x}$',fontsize=20,fontdict=dict(color='red'))
#plt.text(3.1,5,'$\mathcal{x}$',fontsize=20,fontdict=dict(color='red'))

# Add a legend
plt.legend(fontsize='x-small', prop = dict(weight='bold'))
plt.grid(axis = 'y')
# Show the plot
plt.tight_layout()
plt.savefig("BufferTime_Bola_PacketLoss.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
dfbpb = pd.read_csv('/media/lalan/StudyMaterial/WorkingD/Result/BBR_Bola_PacketLoss.csv', index_col=0)
dfbpb2 = pd.read_csv('/media/lalan/StudyMaterial/WorkingD/Result/BBRv2_Bola_PacketLoss.csv', index_col=0)
dfbpc = pd.read_csv('/media/lalan/StudyMaterial/WorkingD/Result/Cubic_Bola_PacketLoss.csv', index_col=0)
dfbpr = pd.read_csv('/media/lalan/StudyMaterial/WorkingD/Result/Reno_Bola_PacketLoss.csv', index_col=0)
dfbpr
# Out:
#              Mean of Buffer Time  Mean of bitrate
# mean of QoE
#  1.800427                    0.0      1230.054904
# -14.852698                  62.0      1268.982629
# -63.227208                 242.8       905.824698
# -87.453170                 332.5       694.371398
# -209.899560                791.0       698.077884

# %%
# Packet Loss vs QoE(TYPE 1 Direct)
# Result  Packet Loss vs Bitrate (Bola)

# Data
bbr_y = np.array([1306.99, 960.71, 815.09, 610.81, 451.68])  # BBR data
bbrv2_y = np.array([1259.38, 985.25, 747.43, 555.47, 357.81])  # BBRv2 data
cubic_y = np.array([1123.29, 970.88, 828.58, 572.82, 382.17])  # Cubic data
reno_y = np.array([1230.05, 1268.98, 905.82, 694.37, 698.07])  # CReno data
1012.86

# Bar width
bar_width = 0.2
plt.figure(figsize=(5,3))
fontsize = 12
fontweight = 'bold'

# Plot bar graphs with logarithmic Y-axis for BBR, BBRv2, Reno, and Cubic
plt.bar(x_positions - 0.4, bbr_y, width=bar_width, label='BBR', hatch='/', color='salmon')
plt.bar(x_positions - 0.2, bbrv2_y, width=bar_width, label='BBRv2', hatch='.', color='darkseagreen')
plt.bar(x_positions, cubic_y, width=bar_width, label='Cubic', hatch='\\', color='bisque')
plt.bar(x_positions + 0.2, reno_y, width=bar_width, label='Reno', hatch='-', color='lightsteelblue')

# Set x-axis labels
#plt.xticks(x_positions, variations)
plt.xticks(x_positions, variations, fontsize=fontsize, fontweight=fontweight)
plt.yticks(fontsize=fontsize, fontweight=fontweight)

# Adding labels and title
plt.xlabel('Packet Loss(in %)', fontweight='bold', fontsize=15)
plt.ylabel('Average Bitrate', fontweight='bold', fontsize=15)
#plt.text(2.9,5,'$\mathcal{x}$',fontsize=20,fontdict=dict(color='red'))
#plt.text(3.1,5,'$\mathcal{x}$',fontsize=20,fontdict=dict(color='red'))

# Add a legend
plt.legend(fontsize='x-small', prop = dict(weight='bold'))
plt.grid(axis = 'y')
# Show the plot
plt.tight_layout()
plt.savefig("AvgBitRate_Bola_PacketLoss.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
####  Bandwidth Variation ####

# %%
#### Throu Bandwidth calculation  ####
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
dftb = pd.read_csv('/media/lalan/StudyMaterial/WorkingD/Result/BBR_Throu_BW.csv', index_col=0)
dftb2 = pd.read_csv('/media/lalan/StudyMaterial/WorkingD/Result/BBRv2_Throu_BW.csv', index_col=0)
dftc = pd.read_csv('/media/lalan/StudyMaterial/WorkingD/Result/Cubic_Throu_BW.csv', index_col=0)
dftr = pd.read_csv('/media/lalan/StudyMaterial/WorkingD/Result/Reno_Throu_BW.csv', index_col=0)

# %%
dftr
# Out:
#              Mean of Buffer Time  Mean of bitrate
# mean of QoE
# 0.000000                       0       200.000000
# 0.051154                       0       200.000000
# 0.913755                       0       454.545455
# 1.380602                       0       942.857143
# 1.611255                       0       996.664044

# %%
# Result  Bandwidth vs QoE(Throughput)

import matplotlib.pyplot as plt
import numpy as np

# Data
variations = [350, 500, 1000, 1500, 2000]
x_positions = np.arange(len(variations))

# Data
bbr_y = np.array([-17.92, 0, 0.89, 1.51, 1.59])  # BBR data
bbrv2_y = np.array([-15.69, 0, 0.88, 1.38, 1.46])  # BBRv2 data
cubic_y = np.array([0, 0.05, 0.42, 1.37, 1.60])  # Cubic data
reno_y = np.array([0, 0.05, 0.91, 1.38, 1.61])  # CReno data


# Bar width
bar_width = 0.2
plt.figure(figsize=(5,3))
fontsize = 12
fontweight = 'bold'
#plt.ylim(-20, 5)
# Plot bar graphs with logarithmic Y-axis for BBR, BBRv2, Reno, and Cubic
plt.bar(x_positions - 0.4, bbr_y, width=bar_width, label='BBR', hatch='/', color='salmon')
plt.bar(x_positions - 0.2, bbrv2_y, width=bar_width, label='BBRv2', hatch='.', color='darkseagreen')
plt.bar(x_positions, cubic_y, width=bar_width, label='Cubic', hatch='\\', color='bisque')
plt.bar(x_positions + 0.2, reno_y, width=bar_width, label='Reno', hatch='-', color='lightsteelblue')

# Set x-axis labels
#plt.xticks(x_positions, variations)
plt.xticks(x_positions, variations, fontsize=fontsize, fontweight=fontweight)
plt.yticks(fontsize=fontsize, fontweight=fontweight)

# Adding labels and title
plt.xlabel('Bandwidth in kbps', fontweight=fontweight, fontsize=15)
plt.ylabel('QoE', fontweight=fontweight, fontsize=15)
#plt.text(2.9,5,'$\mathcal{x}$',fontsize=20,fontdict=dict(color='red'))
#plt.text(3.1,5,'$\mathcal{x}$',fontsize=20,fontdict=dict(color='red'))

# Add a legend
plt.legend(fontsize='x-small', prop = dict(weight='bold'))

# Show the plot
plt.tight_layout()
plt.grid(axis = 'y')
plt.savefig("QoE_BW_Throu.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
dftr
# Out:
#              Mean of Buffer Time  Mean of bitrate
# mean of QoE
# 0.000000                       0       200.000000
# 0.051154                       0       200.000000
# 0.913755                       0       454.545455
# 1.380602                       0       942.857143
# 1.611255                       0       996.664044

# %%
# Result  Bandwidth vs QoE

import matplotlib.pyplot as plt
import numpy as np

# Data
variations = [350, 500, 1000, 1500, 2000]
x_positions = np.arange(len(variations))

# Data
bbr_y = np.array([200, 200, 515.93, 986.66, 774.49])  # BBR data
bbrv2_y = np.array([200, 200, 405.17, 956.19, 759.89])  # BBRv2 data
cubic_y = np.array([200, 200, 496, 964.28, 1034.17])  # Cubic data
reno_y = np.array([200, 200, 454.54, 942.85, 996.66])  # CReno data


# Bar width
bar_width = 0.2
plt.figure(figsize=(5,3))
fontsize = 12
fontweight = 'bold'
#plt.ylim(-20, 5)
# Plot bar graphs with logarithmic Y-axis for BBR, BBRv2, Reno, and Cubic
plt.bar(x_positions - 0.4, bbr_y, width=bar_width, label='BBR', hatch='/', color='salmon')
plt.bar(x_positions - 0.2, bbrv2_y, width=bar_width, label='BBRv2', hatch='.', color='darkseagreen')
plt.bar(x_positions, cubic_y, width=bar_width, label='Cubic', hatch='\\', color='bisque')
plt.bar(x_positions + 0.2, reno_y, width=bar_width, label='Reno', hatch='-', color='lightsteelblue')

# Set x-axis labels
#plt.xticks(x_positions, variations)
plt.xticks(x_positions, variations, fontsize=fontsize, fontweight=fontweight)
plt.yticks(fontsize=fontsize, fontweight=fontweight)

# Adding labels and title
plt.xlabel('Bandwidth in kbps', fontweight=fontweight, fontsize=15)
plt.ylabel('Avg Bitrate', fontweight=fontweight, fontsize=15)
#plt.text(2.9,5,'$\mathcal{x}$',fontsize=20,fontdict=dict(color='red'))
#plt.text(3.1,5,'$\mathcal{x}$',fontsize=20,fontdict=dict(color='red'))

# Add a legend
plt.legend(fontsize='x-small', prop = dict(weight='bold'))

# Show the plot
plt.tight_layout()
plt.grid(axis = 'y')
plt.savefig("AvgBR_BW_Throu.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
#### Bola Bandwidth calculation  ####
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
dfbb = pd.read_csv('/media/lalan/StudyMaterial/WorkingD/Result/BBR_Bola_BW.csv', index_col=0)
dfbb2 = pd.read_csv('/media/lalan/StudyMaterial/WorkingD/Result/BBRv2_Bola_BW.csv', index_col=0)
dfbc = pd.read_csv('/media/lalan/StudyMaterial/WorkingD/Result/Cubic_Bola_BW.csv', index_col=0)
dfbr = pd.read_csv('/media/lalan/StudyMaterial/WorkingD/Result/Reno_Bola_BW.csv', index_col=0)

# %%
dfbr
# Out:
#           0.0.1        200.0
# 0.0
# 0.050722    0.0   200.000000
# 0.917296    0.0   389.090909
# 1.296759    0.0   887.173579
# 1.553280    0.0  1154.775767

# %%
# Result  Bandwidth vs QoE

import matplotlib.pyplot as plt
import numpy as np

# Data
variations = [350, 500, 1000, 1500, 2000]
x_positions = np.arange(len(variations))


# Data
bbr_y = np.array([-13.181472, 0.00, 0.88, 1.38, 1.57])  # BBR data
bbrv2_y = np.array([-19.02, 0.00, 0.86, 1.37, 1.57])  # BBRv2 data
cubic_y = np.array([0.00, 0.02, 0.92, 1.35, 1.59])  # Cubic data
reno_y = np.array([0, 0.05, 0.91, 1.29, 1.55])  # CReno data


# Bar width
bar_width = 0.2
plt.figure(figsize=(5,3))
fontsize = 12
fontweight = 'bold'
plt.ylim(-20, 5)
# Plot bar graphs with logarithmic Y-axis for BBR, BBRv2, Reno, and Cubic
plt.bar(x_positions - 0.4, bbr_y, width=bar_width, label='BBR', hatch='/', color='salmon')
plt.bar(x_positions - 0.2, bbrv2_y, width=bar_width, label='BBRv2', hatch='.', color='darkseagreen')
plt.bar(x_positions, cubic_y, width=bar_width, label='Cubic', hatch='\\', color='bisque')
plt.bar(x_positions + 0.2, reno_y, width=bar_width, label='Reno', hatch='-', color='lightsteelblue')

# Set x-axis labels
#plt.xticks(x_positions, variations)
plt.xticks(x_positions, variations, fontsize=fontsize, fontweight=fontweight)
plt.yticks(fontsize=fontsize, fontweight=fontweight)

# Adding labels and title
plt.xlabel('Bandwidth in kbps', fontweight=fontweight, fontsize=15)
plt.ylabel('QoE value', fontweight=fontweight, fontsize=15)
#plt.text(2.9,5,'$\mathcal{x}$',fontsize=20,fontdict=dict(color='red'))
#plt.text(3.1,5,'$\mathcal{x}$',fontsize=20,fontdict=dict(color='red'))

# Add a legend
plt.legend(fontsize='x-small', prop = dict(weight='bold'))

# Show the plot
plt.tight_layout()
plt.grid(axis = 'y')
plt.savefig("QoEBW_Bola.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
dfbr
# Out:
#           0.0.1        200.0
# 0.0
# 0.050722    0.0   200.000000
# 0.917296    0.0   389.090909
# 1.296759    0.0   887.173579
# 1.553280    0.0  1154.775767

# %%
# Result  Bandwidth vs Buffer Time(Bola)
import matplotlib.pyplot as plt
import numpy as np

# Data
variations = [350, 500, 1000, 1500, 2000]
x_positions = np.arange(len(variations))

# Data
bbr_y = np.array([273.27, 200, 525.18, 961.90, 642])  # BBR data
bbrv2_y = np.array([200, 200, 459, 977.14, 747])  # BBRv2 data
cubic_y = np.array([200, 200, 407, 819.04, 1130])  # Cubic data
reno_y = np.array([200, 200, 389, 887.17, 1154])  # CReno da,ta


# Bar width
bar_width = 0.2
plt.figure(figsize=(5,3))
fontsize = 12
fontweight = 'bold'
#plt.ylim(-20, 5)
# Plot bar graphs with logarithmic Y-axis for BBR, BBRv2, Reno, and Cubic
plt.bar(x_positions - 0.4, bbr_y, width=bar_width, label='BBR', hatch='/', color='salmon')
plt.bar(x_positions - 0.2, bbrv2_y, width=bar_width, label='BBRv2', hatch='.', color='darkseagreen')
plt.bar(x_positions, cubic_y, width=bar_width, label='Cubic', hatch='\\', color='bisque')
plt.bar(x_positions + 0.2, reno_y, width=bar_width, label='Reno', hatch='-', color='lightsteelblue')

# Set x-axis labels
#plt.xticks(x_positions, variations)
plt.xticks(x_positions, variations, fontsize=15, fontweight=fontweight)
plt.yticks(fontsize=15, fontweight=fontweight)

# Adding labels and title
plt.xlabel('Bandwidth in kbps', fontweight=fontweight, fontsize=15)
plt.ylabel('Avg Bitrate', fontweight=fontweight, fontsize=15)
#plt.text(2.9,5,'$\mathcal{x}$',fontsize=20,fontdict=dict(color='red'))
#plt.text(3.1,5,'$\mathcal{x}$',fontsize=20,fontdict=dict(color='red'))

# Add a legend
plt.legend(fontsize='x-small', prop = dict(weight='bold'))

# Show the plot
plt.tight_layout()
plt.grid(axis = 'y')
plt.savefig("AvgBR_BW_Bola.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# Sample data for four algorithms on four data points
algorithms = ['Algorithm 1', 'Algorithm 2', 'Algorithm 3', 'Algorithm 4']
dfb1 = pd.read_csv('/home/lalan/Desktop/MPD/ServerLog/CWND/Result/1%/Bola/BBR_Bola_1_1_cwnd.csv', index_col=0)
dfb2 = pd.read_csv('/home/lalan/Desktop/MPD/ServerLog/CWND/Result/5%/Bola/BBR_Bola_1_5_cwnd.csv', index_col=0)
dfb3 = pd.read_csv('/home/lalan/Desktop/MPD/ServerLog/CWND/Result/10%/Bola/BBR_Bola_1_10_cwnd.csv', index_col=0)
dfbr1 = pd.read_csv('/home/lalan/Desktop/MPD/ServerLog/CWND/Result/1%/Bola/BBRv2_Bola_1_1_cwnd.csv', index_col=0)
dfbr2 = pd.read_csv('/home/lalan/Desktop/MPD/ServerLog/CWND/Result/5%/Bola/BBRv2_Bola_1_5_cwnd.csv', index_col=0)
dfbr3 = pd.read_csv('/home/lalan/Desktop/MPD/ServerLog/CWND/Result/10%/Bola/BBRv2_Bola_1_10_cwnd.csv', index_col=0)
dfc1 = pd.read_csv('/home/lalan/Desktop/MPD/ServerLog/CWND/Result/1%/Bola/Cubic_Bola_1_1_cwnd.csv', index_col=0)
dfc2 = pd.read_csv('/home/lalan/Desktop/MPD/ServerLog/CWND/Result/5%/Bola/Cubic_Bola_1_5_cwnd.csv', index_col=0)
dfc3 = pd.read_csv('/home/lalan/Desktop/MPD/ServerLog/CWND/Result/10%/Bola/Cubic_Bola_5_10_cwnd.csv', index_col=0)
dfr1 = pd.read_csv('/home/lalan/Desktop/MPD/ServerLog/CWND/Result/1%/Bola/Reno_Bola_1_1_cwnd.csv', index_col=0)
dfr2 = pd.read_csv('/home/lalan/Desktop/MPD/ServerLog/CWND/Result/5%/Bola/Reno_Bola_1_5_cwnd.csv', index_col=0)
dfr3 = pd.read_csv('/home/lalan/Desktop/MPD/ServerLog/CWND/Result/10%/Bola/Reno_Bola_3_10_cwnd.csv', index_col=0)
#data_list = [row[1:].tolist() for index, row in df.iterrows()]
#print(dfb1.values.tolist())
# Replace these values with your actual data
df1 = [1, 2, 3, 4]
df2 = [5, 6, 7, 8]
df3 = [9, 10, 11, 12]
df4 = [13, 14, 15, 16]
df5 = [17, 18, 19, 20]
df6 = [21, 22, 23, 24]
# Replace these values with your actual data
algorithm1_data = [[row[1:].tolist() for index, row in dfb1.iterrows()], [row[1:].tolist() for index, row in dfb2.iterrows()], [row[1:].tolist() for index, row in dfb3.iterrows()]]
algorithm2_data = [[row[1:].tolist() for index, row in dfbr1.iterrows()], [row[1:].tolist() for index, row in dfbr2.iterrows()], [row[1:].tolist() for index, row in dfbr3.iterrows()]]
algorithm3_data = [[row[1:].tolist() for index, row in dfc1.iterrows()], [row[1:].tolist() for index, row in dfc2.iterrows()], [row[1:].tolist() for index, row in dfc3.iterrows()]]
algorithm4_data = [[row[1:].tolist() for index, row in dfr1.iterrows()], [row[1:].tolist() for index, row in dfr2.iterrows()], [row[1:].tolist() for index, row in dfr3.iterrows()]]

# Combine the data into a list of lists
data = [algorithm1_data, algorithm2_data, algorithm3_data, algorithm4_data]
# Set the x-axis positions for the boxes
x_positions = [5, 10, 15]

# Plotting the grouped box plot
fig, ax = plt.subplots(figsize=(12, 6))

for i, algo_data in enumerate(data):
    print(i)
    box_positions = [pos + i * 0.2 for pos in x_positions]
    ax.boxplot(algo_data, positions=box_positions, widths=0.2, showfliers=False, patch_artist=True)

# Adding labels and title
plt.xlabel('X-axis Positions', fontweight='bold', fontsize=15)
plt.ylabel('Performance', fontweight='bold', fontsize=15)
plt.title('QoE, CWND vs Packet Losss', fontweight='bold', fontsize=16)

# Adding legend
box_colors = ['blue', 'green', 'red', 'orange']
legend_labels = [plt.Rectangle((0, 0), 1, 1, color=color) for color in box_colors]
ax.legend(legend_labels, algorithms, title='Algorithms', bbox_to_anchor=(1, 1), loc='upper left')

# Show the plot
#plt.show()
